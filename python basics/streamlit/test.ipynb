# %% [markdown]
# Streamlit is an openscource app framework which is used for datascience and machine learning project. you can easily build web application using streamlit components without knowing css or html.
