# %% [markdown]
# covariance

# %%
#used to compare to variable like x and y  how they change together. like x increase y increase or other combinations

# %%
#x increase y increase covariance positive
#x decrease y decrease covariance positive
#x increase y decrease covariance negative
#x decrease y increase covariance negative

# %% [markdown]
# #spearnman correlation

# %% [markdown]
# it is used with non linear and linear data points to record the the correlation as x increase and why also increase or x decrease ad y also decrease

# %% [markdown]
# but  whe correlation is 0.88 for data point x y when they incrase or decrease slowly not drastically like in this figure we use formula to calculate correlation

# %% [markdown]
# open the pdf from the explorer not from vs code go to that folder os statistics than open pdf. see figure
